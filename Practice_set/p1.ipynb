# %%
#1
city = input("Enter city :")
print("City :",city)
# Out:
# City : Surat

# %%
#2
name = "Jemin"
age = 20
percentage = 88

print("name :",name)
print("age: ",age)
print("percentage: ",percentage)
# Out:
# name:  Jemin
# age:  20
# percentage:  88

# %%
#3
color = input("Enter your favorite color :")
print("Your favorite color is :",color)
# Out:
# Your favorite color is : Red

# %%
#4
price = 99.99

print(price)
print(type(price))
# Out:
# 99.99
# <class 'float'>

# %%
#5
a = 42
b = 3.14
c = 2+5j

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
#6
print(10>5)
print(3==7)
print(100>=100)
# Out:
# True
# False
# True

# %%
#7
car = "Mahindra"
print(car[0])
# Out:
# M

# %%
#8
car = "Mahindra"
print(car[3:7])
# Out:
# indr

# %%
#9
name = "Jemin Desai"
print(name[-5:])
# Out:
# Desai

# %%
#10
#ye code name print kar rha he 
print("Jemin")
# Out:
# Jemin

# %%
#11
"""
hello people
this is jemin ramani
thank you
"""
print("Done")
# Out:
# Done

# %%
#12
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#13
"""
1name : invalid
_score : valid
my-var : invalid
total$ : invalid
__init__ : valid
"""

# %%
#14
a = int(input("Enter a number :"))
b = int(input("Enter a number :"))
c = a+b

print("sum of both number is ",c)
# Out:
# sum of both number is  68

# %%
#15
is_eligible = True
print(type(is_eligible))
print(is_eligible)
# Out:
# <class 'bool'>
# True

# %%
#16
sentence = "Data Analytics is fun"

print(sentence[5:14])
# Out:
# Analytics

# %%
#17
name = "Jemin Ramani"

print(f"Hello {name}, welcome to Python!")
# Out:
# Hello Jemin Ramani, welcome to Python!

# %%
#18
a = "OpenAI"
print(a[::-1])
# Out:
# IAnepO

# %%
#19
a = 2
b = 2.3
c = "Jemin"

print(a,b,c)
# Out:
# 2 2.3 Jemin

# %%
#20
age = int(input("Enter your age: "))
born_year = 2026 - age
print(f"You were born in {born_year}.")
# Out:
# You were born in 2005.
