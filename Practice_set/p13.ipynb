# %%
#1
data = { 
    1: "apple", 
    2: "banana", 
    3: "orange" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1

    print(word, count)
# Out:
# apple 2
# banana 3
# orange 3

# %%
#2
data = { 
    1: "python", 
    2: "excel", 
    3: "sql" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# python 1
# excel 2
# sql 0

# %%
#3
data = { 
    1: "computer", 
    2: "keyboard", 
    3: "mouse" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# computer 3
# keyboard 3
# mouse 3

# %%
#4
data = { 
    1: "surat", 
    2: "ahmedabad", 
    3: "vadodara" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# surat 2
# ahmedabad 4
# vadodara 4

# %%
#5
data = { 
    1: "cricket", 
    2: "football", 
    3: "tennis" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# cricket 2
# football 3
# tennis 2

# %%
#6
data = { 
    1: "laptop", 
    2: "mobile", 
    3: "tablet" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# laptop 2
# mobile 3
# tablet 2

# %%
#7
data = { 
    1: "science", 
    2: "maths", 
    3: "english" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# science 3
# maths 1
# english 2

# %%
#8
data = { 
    1: "mango", 
    2: "banana", 
    3: "grapes" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# mango 2
# banana 3
# grapes 2

# %%
#9
data = { 
    1: "amit", 
    2: "rahul", 
    3: "neha" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# amit 2
# rahul 2
# neha 2

# %%
#10
data = { 
    1: "amazon", 
    2: "google", 
    3: "microsoft" 
} 

vowels = "aeiou"

for word in data.values():
    count = 0

    for char in word:
        if char in vowels:
            count += 1
    
    print(word, count)
# Out:
# amazon 3
# google 3
# microsoft 3
