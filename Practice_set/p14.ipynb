# %%
#1
students = { 
    "Rahul": 75, 
    "Amit": 55, 
    "Neha": 82, 
    "Ravi": 68 
} 

for key, value in students.items(): 
    if 60 <= value <= 80: 
        print(key)
# Out:
# Rahul
# Ravi

# %%
#2
students = { 
    "A": 61, 
    "B": 45, 
    "C": 79, 
    "D": 90 
} 

for key, value in students.items():
    if 60 <= value <= 80:
        print(key)
# Out:
# A
# C

# %%
#3
employees = { 
    "Amit": 65000, 
    "Neha": 45000, 
    "Jay": 78000, 
    "Ravi": 85000 
} 

for key, value in employees.items():
    if 60000 <= value <= 80000:
        print(key)
# Out:
# Amit
# Jay

# %%
#4
products = { 
    "Laptop": 55000, 
    "Mobile": 30000, 
    "Tablet": 25000, 
    "TV": 70000 
} 

for key, value in products.items():
    if 25000 <= value <= 60000:
        print(key)
# Out:
# Laptop
# Mobile
# Tablet

# %%
#5
cities = { 
    "Ahmedabad": 8500000, 
    "Surat": 7200000, 
    "Rajkot": 1800000, 
    "Vadodara": 2200000 
} 

for key, value in cities.items():
    if 2000000 <= value <= 8000000:
        print(key)
# Out:
# Surat
# Vadodara

# %%
#6
courses = { 
    "Python": 3, 
    "SQL": 2, 
    "Excel": 1, 
    "Data Science": 6 
} 

for key, value in courses.items():
    if 2 <= value <= 5:
        print(key)
# Out:
# Python
# SQL

# %%
#7
movies = { 
    "3 Idiots": 8.4, 
    "PK": 8.1, 
    "Dangal": 8.3, 
    "Movie X": 7.2 
} 

for key, value in movies.items():
    if 8.0 <= value <= 8.3:
        print(key)
# Out:
# PK
# Dangal

# %%
#8
books = { 
    "Atomic Habits": 499, 
    "Deep Work": 550, 
    "Ikigai": 350, 
    "Book X": 800 
} 

for key, value in books.items():
    if 300 <= value <= 600:
        print(key)
# Out:
# Atomic Habits
# Deep Work
# Ikigai

# %%
#9
fruits = { 
    "Apple": 120, 
    "Mango": 150, 
    "Banana": 60, 
    "Orange": 90 
} 

for key, value in fruits.items():
    if 80 <= value <= 130:
        print(key)
# Out:
# Apple
# Orange

# %%
#10
subjects = { 
    "Maths": 88, 
    "Science": 95, 
    "English": 82, 
    "History": 76 
} 

for key, value in subjects.items():
    if 75 <= value <= 90:
        print(key)
# Out:
# Maths
# English
# History
