# %%
#1
data = { 
    "A": 80, 
    "B": 95, 
    "C": 70, 
    "D": 90 
} 

values = sorted(data.values(),reverse=True)
print(values[1])
# Out:
# 90

# %%
#2
students = { 
    "Rahul": 78, 
    "Amit": 92, 
    "Neha": 85, 
    "Ravi": 88 
} 

values = sorted(students.values(),reverse=True)
print(values[1])
# Out:
# 88

# %%
#3
employees = { 
    "Amit": 45000, 
    "Neha": 62000, 
    "Jay": 58000, 
    "Ravi": 70000 
} 

values = sorted(employees.values(),reverse=True)
print(values[1])
# Out:
# 62000

# %%
#4
products = { 
    "Laptop": 55000, 
    "Mobile": 30000, 
    "Tablet": 25000, 
    "TV": 70000 
} 

sort = sorted(products.items(),key=lambda x:x[1], reverse=True)
print(sort[1])
# Out:
# ('Laptop', 55000)

# %%
#5
cities = { 
    "Ahmedabad": 8500000, 
    "Surat": 7200000, 
    "Vadodara": 2200000, 
    "Rajkot": 1800000 
} 

sort = sorted(cities.items(),key=lambda x:x[1], reverse=True)
print(sort[1])
# Out:
# ('Surat', 7200000)

# %%
#6
courses = { 
    "Python": 3, 
    "SQL": 2, 
    "Excel": 1, 
    "Data Science": 6 
} 

sort = sorted(courses.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Python', 3)

# %%
#7
movies = { 
    "3 Idiots": 8.4, 
    "Dangal": 8.3, 
    "PK": 8.1, 
    "Lagaan": 8.2 
} 

sort = sorted(movies.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Dangal', 8.3)

# %%
#8
books = { 
    "Atomic Habits": 499, 
    "Deep Work": 550, 
    "The Alchemist": 299, 
    "Ikigai": 350 
} 

sort = sorted(books.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Atomic Habits', 499)

# %%
#9
fruits = { 
    "Apple": 120, 
    "Mango": 150, 
    "Banana": 60, 
    "Orange": 90 
} 

sort = sorted(fruits.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Apple', 120)

# %%
#10
subjects = { 
    "Maths": 88, 
    "Science": 95, 
    "English": 82, 
    "History": 76 
} 

sort = sorted(subjects.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Maths', 88)
