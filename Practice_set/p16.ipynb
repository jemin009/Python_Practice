# %%
#1
students = { 
    "Rahul": 78, 
    "Amit": 92, 
    "Neha": 85, 
    "Ravi": 88 
} 

sort = sorted(students.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Ravi', 88)

# %%
#2
employees = { 
    "Amit": 45000, 
    "Neha": 62000, 
    "Jay": 58000, 
    "Ravi": 70000 
} 

sort = sorted(employees.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Neha', 62000)

# %%
#3
products = { 
    "Laptop": 55000, 
    "Mobile": 30000, 
    "Tablet": 25000, 
    "TV": 70000 
} 

sort = sorted(products.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Laptop', 55000)

# %%
#4
cities = { 
    "Ahmedabad": 8500000, 
    "Surat": 7200000, 
    "Vadodara": 2200000, 
    "Rajkot": 1800000 
} 

sort = sorted(cities.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Surat', 7200000)

# %%
#5
courses = { 
    "Python": 3, 
    "SQL": 2, 
    "Excel": 1, 
    "Data Science": 6 
} 

sort = sorted(courses.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Python', 3)

# %%
#6
movies = { 
    "3 Idiots": 8.4, 
    "Dangal": 8.3, 
    "PK": 8.1, 
    "Lagaan": 8.2 
} 

sort = sorted(movies.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Dangal', 8.3)

# %%
#7
books = { 
    "Atomic Habits": 499, 
    "Deep Work": 550, 
    "The Alchemist": 299, 
    "Ikigai": 350 
} 

sort = sorted(books.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Atomic Habits', 499)

# %%
#8
fruits = { 
    "Apple": 120, 
    "Mango": 150, 
    "Banana": 60, 
    "Orange": 90 
} 

sort = sorted(fruits.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Apple', 120)

# %%
#9
subjects = { 
    "Maths": 88, 
    "Science": 95, 
    "English": 82, 
    "History": 76 
} 

sort = sorted(subjects.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('Maths', 88)

# %%
#10
teams = { 
    "India": 275, 
    "Australia": 310, 
    "England": 295, 
    "South Africa": 260 
} 

sort = sorted(teams.items(),key=lambda x:x[1],reverse=True)
print(sort[1])
# Out:
# ('England', 295)
