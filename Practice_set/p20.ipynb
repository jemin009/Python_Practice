# %%
#1
languages = ["python", "sql", "excel"] 

new = [i.upper() for i in languages]
print(new)
# Out:
# ['PYTHON', 'SQL', 'EXCEL']

# %%
#2
cities = ["surat", "ahmedabad", "vadodara"] 

new = [i.upper() for i in cities]
print(new)
# Out:
# ['SURAT', 'AHMEDABAD', 'VADODARA']

# %%
#3
students = ["rahul", "amit", "neha"] 

new = [i.upper() for i in students]
print(new)
# Out:
# ['RAHUL', 'AMIT', 'NEHA']

# %%
#4
fruits = ["apple", "banana", "mango"] 

new = [i.upper() for i in fruits]
print(new)
# Out:
# ['APPLE', 'BANANA', 'MANGO']

# %%
#5
courses = ["power bi", "tableau", "data science"] 

new = [i.upper() for i in courses]
print(new)
# Out:
# ['POWER BI', 'TABLEAU', 'DATA SCIENCE']

# %%
#6
countries = ["india", "japan", "canada"] 

new = [i.upper() for i in countries]
print(new)
# Out:
# ['INDIA', 'JAPAN', 'CANADA']

# %%
#7
subjects = ["maths", "science", "english"] 

new = [i.upper() for i in subjects]
print(new)
# Out:
# ['MATHS', 'SCIENCE', 'ENGLISH']

# %%
#8
companies = ["google", "amazon", "microso "] 

new = [i.upper() for i in companies]
print(new)
# Out:
# ['GOOGLE', 'AMAZON', 'MICROSO ']

# %%
#9
sports = ["cricket", "football", "tennis"] 

new = [i.upper() for i in sports]
print(new)
# Out:
# ['CRICKET', 'FOOTBALL', 'TENNIS']

# %%
#10
movies = ["dangal", "pk", "lagaan"] 

new = [i.upper() for i in movies]
print(new)
# Out:
# ['DANGAL', 'PK', 'LAGAAN']
