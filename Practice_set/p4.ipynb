# %%
#1
fruits = ["Apple","Mango","Banana","Orange"]
print(fruits)
# Out:
# ['Apple', 'Mango', 'Banana', 'Orange']

# %%
#2
fruits = ["Apple","Mango","Banana","Orange"]
print(fruits[0])
# Out:
# Apple

# %%
#3
fruits = ["Apple","Mango","Banana","Orange"]
print(fruits[-1:])
# Out:
# ['Orange']

# %%
#4
numbers = [10,20,30,40,50]
print(numbers[2])
# Out:
# 30

# %%
#5
colors = ["Red","Blue","Green"]
colors.append("Yellow")

print(colors)
# Out:
# ['Red', 'Blue', 'Green', 'Yellow']

# %%
#6
cities = ["Ahmedabad", "Surat", "Vadodara"] 
cities.remove('Surat')

print(cities)
# Out:
# ['Ahmedabad', 'Vadodara']

# %%
#7
marks = [75, 80, 90, 65, 85] 
print(len(marks))
# Out:
# 5

# %%
#8
numbers = [5, 10, 15, 20] 
print(numbers[0]+numbers[1]+numbers[2]+numbers[3])
# Out:
# 50

# %%
#9
numbers = [12, 25, 8, 40, 17] 
print(max(numbers))
# Out:
# 40

# %%
#10
numbers = [12, 25, 8, 40, 17] 
print(min(numbers))
# Out:
# 8

# %%
#11
months = ("Jan", "Feb", "Mar", "Apr") 
print(months)
# Out:
# ('Jan', 'Feb', 'Mar', 'Apr')

# %%
#12
months = ("Jan", "Feb", "Mar", "Apr") 
print(months[1])
# Out:
# Feb

# %%
#13
numbers = (10, 20, 30, 40, 50) 
print(numbers[-1:])
# Out:
# (50,)

# %%
#14
subjects = ("Maths", "Science", "English", "Computer") 
print(len(subjects))
# Out:
# 4

# %%
#15
numbers = (5, 10, 15, 20, 25) 
print(15 in numbers)
# Out:
# True

# %%
#16
colors = {"Red", "Blue", "Green"} 
print(colors)
# Out:
# {'Red', 'Blue', 'Green'}

# %%
#17
colors = {"Red", "Blue", "Green"} 
colors.add("Yellow")

print(colors)
# Out:
# {'Red', 'Yellow', 'Blue', 'Green'}

# %%
#18
numbers = {10, 20, 30, 40} 
numbers.remove(20)

print(numbers)
# Out:
# {40, 10, 30}

# %%
#19
animals = {"Dog", "Cat", "Lion", "Tiger"} 
print(len(animals))
# Out:
# 4

# %%
#20
numbers = {5, 10, 15, 20} 
print(15 in numbers)
# Out:
# True

# %%
#21
student = { 
    "name": "Rahul", 
    "age": 20, 
    "city": "Ahmedabad" 
}

print(student)
# Out:
# {'name': 'Rahul', 'age': 20, 'city': 'Ahmedabad'}

# %%
#22
student = { 
    "name": "Rahul", 
    "age": 20, 
    "city": "Ahmedabad" 
}

print(student["name"])
# Out:
# Rahul

# %%
#23
student = { 
    "name": "Rahul", 
    "age": 20, 
    "city": "Ahmedabad" 
}

print(student["city"])
# Out:
# Ahmedabad

# %%
#24
employee = { 
    "name": "Amit", 
    "salary": 50000 
} 

employee["department"]="IT"

print(employee)
# Out:
# {'name': 'Amit', 'salary': 50000, 'department': 'IT'}

# %%
#25
car = { 
    "brand": "Toyota", 
    "model": "Innova", 
    "year": 2024 
} 

print(car.keys())
# Out:
# dict_keys(['brand', 'model', 'year'])

# %%
#26
car = { 
    "brand": "Toyota", 
    "model": "Innova", 
    "year": 2024 
} 

print(car.values())
# Out:
# dict_values(['Toyota', 'Innova', 2024])

# %%
#27
product = { 
    "name": "Laptop", 
    "price": 55000, 
    "stock": 25 
} 

print(len(product))
# Out:
# 3

# %%
#28
student = { 
    "name": "Neha", 
    "marks": 88 
} 

print("marks" in student)
# Out:
# True

# %%
#29
country = { 
"India": "New Delhi", 
"Japan": "Tokyo", 
"France": "Paris" 
} 

print(country["Japan"])
# Out:
# Tokyo

# %%
#30
person = { 
"name": "Jay", 
"age": 22 
} 

person['city']="Surat"

print(person)
# Out:
# {'name': 'Jay', 'age': 22, 'city': 'Surat'}
