# %%
#1
countries = {
    "India": "New Delhi",
    "Japan": "Tokyo",
    "France": "Paris",
    "Australia": "Canberra",
    "Brazil": "Brasilia"
}

for i in countries:
    print(i)
# Out:
# India
# Japan
# France
# Australia
# Brazil

# %%
#2
students = {
    "Rahul": 78,
    "Amit": 92,
    "Neha": 85,
    "Priya": 88,
    "Jay": 74
}

for i in students:
    print(i)
# Out:
# Rahul
# Amit
# Neha
# Priya
# Jay

# %%
#3
cities = {
    "Ahmedabad": 8500000,
    "Surat": 7200000,
    "Vadodara": 2200000,
    "Rajkot": 1800000,
    "Bhavnagar": 700000
}

for i in cities:
    print(i)
# Out:
# Ahmedabad
# Surat
# Vadodara
# Rajkot
# Bhavnagar

# %%
#4
books = {
    "Atomic Habits": 499,
    "Rich Dad Poor Dad": 399,
    "The Alchemist": 299,
    "Think and Grow Rich": 450,
    "Deep Work": 550
}

for i in books:
    print(i)
# Out:
# Atomic Habits
# Rich Dad Poor Dad
# The Alchemist
# Think and Grow Rich
# Deep Work

# %%
#5
employees = {
    "Amit": "IT",
    "Neha": "HR",
    "Jay": "Finance",
    "Priya": "Marketing",
    "Rahul": "Sales"
}

for i in employees:
    print(i)
# Out:
# Amit
# Neha
# Jay
# Priya
# Rahul

# %%
#6
mobiles = {
    "Samsung": "Galaxy S25",
    "Apple": "iPhone 17",
    "OnePlus": "13R",
    "Xiaomi": "15 Pro",
    "Google": "Pixel 11"
}

for i in mobiles:
    print(i)
# Out:
# Samsung
# Apple
# OnePlus
# Xiaomi
# Google

# %%
#7
courses = {
    "Python": "3 Months",
    "SQL": "2 Months",
    "Excel": "1 Month",
    "Power BI": "2 Months",
    "Data Science": "6 Months"
}

for i in courses:
    print(i)
# Out:
# Python
# SQL
# Excel
# Power BI
# Data Science

# %%
#8
fruits = {
    "Apple": "Red",
    "Banana": "Yellow",
    "Mango": "Orange",
    "Grapes": "Green",
    "Orange": "Orange"
}

for i in fruits:
    print(i)
# Out:
# Apple
# Banana
# Mango
# Grapes
# Orange

# %%
#9
subjects = {
    "Mathematics": "Mr. Sharma",
    "Science": "Mrs. Patel",
    "English": "Ms. Mehta",
    "Computer": "Mr. Verma",
    "History": "Mrs. Joshi"
}

for i in subjects:
    print(i)
# Out:
# Mathematics
# Science
# English
# Computer
# History

# %%
#10
movies = {
    "3 Idiots": 2009,
    "Dangal": 2016,
    "PK": 2014,
    "Bahubali": 2015,
    "Pushpa": 2021
}

for i in movies:
    print(i)
# Out:
# 3 Idiots
# Dangal
# PK
# Bahubali
# Pushpa
