# %%
#1
students = {
    "Rahul": 85,
    "Priya": 72,
    "Aman": 65,
    "Sneha": 91,
    "Rohit": 45,
    "Anjali": 78,
    "Vikas": 95,
    "Neha": 68
}

for i in students:
    if students[i] > 70:
        print(i)
# Out:
# Rahul
# Priya
# Sneha
# Anjali
# Vikas

# %%
#2
employees = {
    "Amit": 65000,
    "Neha": 45000,
    "Rahul": 38000,
    "Sneha": 72000,
    "Vikas": 29000,
    "Priya": 48000,
    "Rohit": 55000,
    "Anjali": 35000
}

for i in employees:
    if employees[i] > 40000:
        print(i)
# Out:
# Amit
# Neha
# Sneha
# Priya
# Rohit

# %%
#3
products = {
    "Laptop": 65000,
    "Mouse": 800,
    "Keyboard": 1200,
    "Mobile": 35000,
    "Charger": 900,
    "Headphones": 2500,
    "Monitor": 18000,
    "Pendrive": 700
}

for i in products:
    if products[i] > 1000:
        print(i)
# Out:
# Laptop
# Keyboard
# Mobile
# Headphones
# Monitor

# %%
#4
cities = {
    "Mumbai": 12478447,
    "Delhi": 16787941,
    "Bangalore": 8443675,
    "Ahmedabad": 6357693,
    "Chennai": 7090000,
    "Hyderabad": 6809000,
    "Pune": 3125000,
    "Jaipur": 3072000,
    "Surat": 4462000
}

for i in cities:
    if cities[i] > 2000000:
        print(i)
# Out:
# Mumbai
# Delhi
# Bangalore
# Ahmedabad
# Chennai
# Hyderabad
# Pune
# Jaipur
# Surat

# %%
#5
courses = {
    "Python": 6,
    "Excel": 2,
    "SQL": 4,
    "Power BI": 3,
    "Java": 8,
    "HTML": 1,
    "Data Science": 7,
    "C++": 5,
    "JavaScript": 4
}

for i in courses:
    if courses[i] > 3:
        print(i)
# Out:
# Python
# SQL
# Java
# Data Science
# C++
# JavaScript

# %%
#6
players = {
    "Virat": 87,
    "Rohit": 45,
    "Rahul": 62,
    "Dhoni": 78,
    "Hardik": 55,
    "Surya": 42,
    "Jadeja": 91,
    "Bumrah": 38,
    "Pant": 72
}

for i in players:
    if players[i] > 50:
        print(i)
# Out:
# Virat
# Rahul
# Dhoni
# Hardik
# Jadeja
# Pant

# %%
#7
books = {
    "Python Programming": 450,
    "Rich Dad Poor Dad": 280,
    "Atomic Habits": 320,
    "The Alchemist": 180,
    "Clean Code": 460,
    "Harry Potter": 650,
    "The Psychology of Money": 250,
    "Deep Work": 380,
    "Ikigai": 190
}

for i in books:
    if books[i] > 300:
        print(i)
# Out:
# Python Programming
# Atomic Habits
# Clean Code
# Harry Potter
# Deep Work

# %%
#8
fruits = {
    "Apple": 35,
    "Banana": 80,
    "Mango": 15,
    "Orange": 25,
    "Grapes": 45,
    "Pineapple": 12,
    "Strawberry": 28,
    "Watermelon": 8,
    "Guava": 22
}

for i in fruits:
    if fruits[i] > 20:
        print(i)
# Out:
# Apple
# Banana
# Orange
# Grapes
# Strawberry
# Guava

# %%
#9
mobile_brands = {
    "Samsung": 12500,
    "Apple": 9800,
    "Xiaomi": 6700,
    "Vivo": 4200,
    "Oppo": 3800,
    "Realme": 5400,
    "OnePlus": 3100,
    "Motorola": 2800,
    "Nokia": 1500
}

for i in mobile_brands:
    if mobile_brands[i] > 5000:
        print(i)
# Out:
# Samsung
# Apple
# Xiaomi
# Realme

# %%
#10
movies = {
    "Oppenheimer": 8.5,
    "Joker": 8.4,
    "Inception": 8.8,
    "Interstellar": 8.7,
    "The Dark Knight": 9.0,
    "Avengers": 7.8,
    "Dune": 8.0,
    "Parasite": 8.5,
    "Fight Club": 8.8,
    "The Matrix": 8.7
}

for i in movies:
    if movies[i] > 8:
        print(i)
# Out:
# Oppenheimer
# Joker
# Inception
# Interstellar
# The Dark Knight
# Parasite
# Fight Club
# The Matrix
